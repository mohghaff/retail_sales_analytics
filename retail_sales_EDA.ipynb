# %%
import pandas as pd
import numpy as np

# %%
#Importing the dataset from Kaggle
! pip install kaggle
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d mohammadtalib786/retail-sales-dataset
# Out:
# ...
#   0% 0.00/11.2k [00:00<?, ?B/s]
# 100% 11.2k/11.2k [00:00<00:00, 26.4MB/s]

# %%
! unzip retail-sales-dataset.zip
# Out:
# Archive:  retail-sales-dataset.zip
#   inflating: retail_sales_dataset.csv

# %%
df = pd.read_csv('/content/retail_sales_dataset.csv')

# %%
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %% [markdown]
# **Checking Data Type Compatibility**

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Transaction ID       int64
# Date                object
# Customer ID         object
# Gender              object
# Age                  int64
# Product Category    object
# Quantity             int64
# Price per Unit       int64
# Total Amount         int64
# dtype: object

# %%
numeric_cols = df.select_dtypes(include=[np.number])
numeric_cols.head()
# Out:
#    Transaction ID  Age  Quantity  Price per Unit  Total Amount
# 0               1   34         3              50           150
# 1               2   26         2             500          1000
# 2               3   50         1              30            30
# 3               4   37         1             500           500
# 4               5   30         2              50           100

# %% [markdown]
# **Checking Null Values**

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Transaction ID      1000
# Date                1000
# Customer ID         1000
# Gender              1000
# Age                 1000
# Product Category    1000
# Quantity            1000
# Price per Unit      1000
# Total Amount        1000
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# **Checking Duplicate Values**

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
print('Gender :', df['Gender'].unique().tolist())
print('Category :', df['Product Category'].unique().tolist())
# Out:
# Gender : ['Male', 'Female']
# Category : ['Beauty', 'Clothing', 'Electronics']

# %% [markdown]
# **Exploring Customer Age Distribution**

# %%
age_ranges = df.groupby('Gender')['Age'].agg(['min', 'max'])

print(age_ranges)
# Out:
#         min  max
# Gender
# Female   18   64
# Male     18   64

# %%
average_age = df.groupby('Gender')['Age'].agg('mean').round(2)
average_age
# Out:
# Gender
# Female    41.36
# Male      41.43
# Name: Age, dtype: float64

# %% [markdown]
# **Exploring Data Correlation**

# %%
df.drop('Transaction ID', axis=1).corr(numeric_only=True)
# Out:
#                      Age  Quantity  Price per Unit  Total Amount
# Age             1.000000 -0.023737       -0.038423     -0.060568
# Quantity       -0.023737  1.000000        0.017501      0.373707
# Price per Unit -0.038423  0.017501        1.000000      0.851925
# Total Amount   -0.060568  0.373707        0.851925      1.000000
